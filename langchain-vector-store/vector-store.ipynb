# %%
print("Hello")
# Out:
# Hello

# %%
# !pip install langchain chromadb langchain-groq pypdf langchain-community tiktoken
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 70.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.5/395.5 kB 25.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 66.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 17.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 9.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 85.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 44.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.6/23.6 MB 52.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.2/137.2 kB 9.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 4.6 MB/s eta 0:00:00
# ...

# %%
# !pip install faiss-cpu
# !pip install langchain-huggingface

# %%
from langchain_core.documents import Document
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)
# Out:
# /tmp/ipykernel_3048/4176361470.py:3: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.vectorstores import FAISS
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
from langchain_core.documents import Document

documents = [

    Document(
        page_content="""
        Virat Kohli is an Indian right-handed batter who plays for
        Royal Challengers Bengaluru (RCB) in the Indian Premier League.
        He is one of the most experienced players in IPL history and has
        been closely associated with RCB throughout his IPL career.
        Kohli is primarily known for his batting and has also served as
        captain of RCB in previous IPL seasons.
        """,
        metadata={
            "player": "Virat Kohli",
            "team": "Royal Challengers Bengaluru",
            "role": "Batter",
            "country": "India"
        }
    ),

    Document(
        page_content="""
        Rohit Sharma is an Indian right-handed opening batter who plays
        for Mumbai Indians (MI). He has been one of the most successful
        captains in IPL history and has won multiple IPL titles with
        Mumbai Indians. Rohit is known for his opening batting and
        leadership experience.
        """,
        metadata={
            "player": "Rohit Sharma",
            "team": "Mumbai Indians",
            "role": "Batter",
            "country": "India"
        }
    ),

    Document(
        page_content="""
        Ravindra Jadeja is an Indian left-handed all-rounder and
        left-arm orthodox spinner. He has represented Chennai Super Kings
        for many seasons and has also played for Rajasthan Royals.
        Jadeja contributes to matches with batting, bowling and fielding.
        For IPL 2026, he moved from Chennai Super Kings to Rajasthan Royals
        through a player trade.
        """,
        metadata={
            "player": "Ravindra Jadeja",
            "team": "Rajasthan Royals",
            "role": "All-rounder",
            "country": "India"
        }
    ),

    Document(
        page_content="""
        Jasprit Bumrah is an Indian right-arm fast bowler who plays for
        Mumbai Indians. He is known for his pace, yorkers, variations and
        ability to bowl effectively during the death overs. Bumrah has
        been an important bowling option for Mumbai Indians as well as
        the Indian cricket team.
        """,
        metadata={
            "player": "Jasprit Bumrah",
            "team": "Mumbai Indians",
            "role": "Bowler",
            "country": "India"
        }
    ),

    Document(
        page_content="""
        Shubman Gill is an Indian right-handed batter who represents
        Gujarat Titans. He has been associated with Gujarat Titans since
        the franchise's early IPL seasons and has also served as captain.
        Gill is primarily an opening or top-order batter.
        """,
        metadata={
            "player": "Shubman Gill",
            "team": "Gujarat Titans",
            "role": "Batter",
            "country": "India"
        }
    ),

    Document(
        page_content="""
        Rashid Khan is an Afghanistan international cricketer and a
        right-arm leg-spin bowler who plays for Gujarat Titans. He is
        regarded as a high-impact T20 spinner and can also contribute
        useful runs with the bat. Rashid has been an important player
        for Gujarat Titans since the franchise's early seasons.
        """,
        metadata={
            "player": "Rashid Khan",
            "team": "Gujarat Titans",
            "role": "All-rounder",
            "country": "Afghanistan"
        }
    ),

    Document(
        page_content="""
        Rishabh Pant is an Indian left-handed wicketkeeper-batter.
        He previously played for Lucknow Super Giants and returned to
        Delhi Capitals in 2026 through a player trade. Pant has been
        associated with Delhi Capitals for a large part of his IPL
        career and has also captained the franchise.
        """,
        metadata={
            "player": "Rishabh Pant",
            "team": "Delhi Capitals",
            "role": "Wicketkeeper-Batter",
            "country": "India"
        }
    ),

    Document(
        page_content="""
        Pat Cummins is an Australian right-arm fast bowler and captain
        of Sunrisers Hyderabad. He is known for his pace, accuracy and
        leadership. Cummins can contribute with both bowling and lower-
        order batting and has extensive international cricket experience.
        """,
        metadata={
            "player": "Pat Cummins",
            "team": "Sunrisers Hyderabad",
            "role": "Bowler",
            "country": "Australia"
        }
    ),

    Document(
        page_content="""
        Sanju Samson is an Indian right-handed wicketkeeper-batter.
        He has spent most of his IPL career with Rajasthan Royals and
        has also captained the franchise. In the 2026 season, Samson
        moved from Rajasthan Royals to Chennai Super Kings through a
        player trade.
        """,
        metadata={
            "player": "Sanju Samson",
            "team": "Chennai Super Kings",
            "role": "Wicketkeeper-Batter",
            "country": "India"
        }
    ),

    Document(
        page_content="""
        Travis Head is an Australian left-handed batter who plays for
        Sunrisers Hyderabad. He is an aggressive top-order batter and
        is particularly known for attacking batting during the powerplay.
        Head has represented Australia across multiple formats and is
        an important overseas batter in the IPL.
        """,
        metadata={
            "player": "Travis Head",
            "team": "Sunrisers Hyderabad",
            "role": "Batter",
            "country": "Australia"
        }
    )
]

# %%
vector_store = FAISS.from_documents(
    documents,
    embeddings
)

vector_store.save_local("faiss_index")

# %%
search_result = vector_store.similarity_search_with_score("Who plays for Hydrabad ?", k=2)
search_result
# Out:
# [(Document(id='31fd73fd-79ff-416b-9459-eb9f5ce52fbf', metadata={'player': 'Sanju Samson', 'team': 'Chennai Super Kings', 'role': 'Wicketkeeper-Batter', 'country': 'India'}, page_content='\n        Sanju Samson is an Indian right-handed wicketkeeper-batter.\n        He has spent most of his IPL career with Rajasthan Royals and\n        has also captained the franchise. In the 2026 season, Samson\n        moved from Rajasthan Royals to Chennai Super Kings through a\n        player trade.\n        '),
#   np.float32(1.3385415)),
# ...
